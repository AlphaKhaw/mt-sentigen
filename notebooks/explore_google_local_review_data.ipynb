# %% [markdown]
# # Exploration of Google Local Data (2021)
#
# ### Table of Contents
#
# 1. [Import Packages](#import)
# 2. [Webscrape and Parse URL](#webscrape)
# 3. [Display Tables of Interest](#table)
# 4. [Extract Download Links](#extract)
# 5. [Download and Explore Data](#download)
# 6. [Summary](#summary)
#
# **Objective:**
#
# The main objective of this notebook is to explore the `Google Local Data (2021)` and extract important statistics for subsequent **Exploratory Data Analysis (EDA)**.
#
# **Description**
#
# This Dataset contains review information on Google map (ratings, text, images, etc.), business metadata (address, geographical info, descriptions, category information, price, open hours, and MISC info), and links (relative businesses) up to Sep 2021 in the United States.

# %% [markdown]
# ## 1. Import Packages<a class="anchor" id="import"></a>

# %%
import os
import requests
import sys

import pandas as pd
from bs4 import BeautifulSoup
from IPython.display import display, HTML

sys.path.append("../src/utils/eda")

from eda_utils import (
    download_file, parse_into_dataframe, remove_files_from_folder
)

# %% [markdown]
# ## 2. Webscrape and Parse URL<a class="anchor" id="webscrape"></a>
#
#
# In the notebook, we analyzed the `Google Local Data (2021)` available through the provided URL. Within this data, we identified three key tables of interest:
#
# 1. The first table is a summary table presenting essential statistics, including the total number of reviews, users, and businesses in the dataset.
# 2. The second table contains comprehensive review data, organized by states, along with the corresponding review counts and metadata for each state.
# 3. Lastly, the third table comprises a subset of review data, also organized by states, but this time featuring k-core reviews and ratings for each state.
#
# These tables serve as valuable sources of information for further analysis and insights into the Google Local Data.

# %% [markdown]
# **Retrieves and Parses contents of URL using `requests` and `BeautifulSoup4`:**

# %%
url = "https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# **Locate all three tables of interest:**

# %%
summary_table = soup.find(
    lambda tag: tag.name=='table' and 
    tag.findChild('td').contents == ['Reviews:']
)
complete_data_table = soup.find(
    lambda tag: tag.name=='table' and 
    "reviews" in tag.findChildren('td')[1].get_text()
)
subset_data_table = soup.find(
    lambda tag: tag.name=='table' and 
    "10-core" in tag.findChildren('td')[1].get_text()
)

# %% [markdown]
# ## 3. Display Tables of Interest<a class="anchor" id="table"></a>
#
#
# ### A. Summary Table
#
# Here are the following summary statistics of `Google Local Data (2021)`:
# - **666,324,103** reviews
# - **113,643,107** users
# - **4,963,111** businesses

# %%
display(HTML(summary_table.prettify()))
# Out:
# <table class="code-table">
#  <tr>
#   <td>
#    Reviews:
#   </td>
#   <td>
#    666,324,103
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Users:
#   </td>
#   <td>
#    113,643,107
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Businesses:
#   </td>
#   <td>
#    4,963,111
#   </td>
#  </tr>
# </table>

# %% [markdown]
# ### B. Complete Review Data Table

# %%
display(HTML(complete_data_table.prettify()))
# Out:
# <table class="code-table" style="font-size: 0.7em; width:90%">
#  <tr>
#   <td>
#    Alabama
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Alabama.json.gz">
#     reviews
#    </a>
#    (8,967,499 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Alabama.json.gz">
#     metadata
#    </a>
#    (74,967 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Alaska
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Alaska.json.gz">
#     reviews
#    </a>
#    (1,051,246 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Alaska.json.gz">
#     metadata
#    </a>
#    (12,774 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Arizona
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Arizona.json.gz">
#     reviews
#    </a>
#    (18,375,050 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Arizona.json.gz">
#     metadata
#    </a>
#    (108,579 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Arkansas
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Arkansas.json.gz">
#     reviews
#    </a>
#    (5,106,056 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Arkansas.json.gz">
#     metadata
#    </a>
#    (47,246 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    California
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-California.json.gz">
#     reviews
#    </a>
#    (70,529,977 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-California.json.gz">
#     metadata
#    </a>
#    (515,961 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Colorado
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Colorado.json.gz">
#     reviews
#    </a>
#    (15,681,222 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Colorado.json.gz">
#     metadata
#    </a>
#    (106,829 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Connecticut
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Connecticut.json.gz">
#     reviews
#    </a>
#    (5,181,800 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Connecticut.json.gz">
#     metadata
#    </a>
#    (49,200 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Delaware
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Delaware.json.gz">
#     reviews
#    </a>
#    (1,885,948 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Delaware.json.gz">
#     metadata
#    </a>
#    (14,706 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    District of Columbia
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-District_of_Columbia.json.gz">
#     reviews
#    </a>
#    (1,894,317 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-District_of_Columbia.json.gz">
#     metadata
#    </a>
#    (11,060 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Florida
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Florida.json.gz">
#     reviews
#    </a>
#    (61,803,524 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Florida.json.gz">
#     metadata
#    </a>
#    (378,020 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Georgia
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Georgia.json.gz">
#     reviews
#    </a>
#    (24,060,125 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Georgia.json.gz">
#     metadata
#    </a>
#    (166,381 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Hawaii
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Hawaii.json.gz">
#     reviews
#    </a>
#    (3,111,531 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Hawaii.json.gz">
#     metadata
#    </a>
#    (21,507 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Idaho
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Idaho.json.gz">
#     reviews
#    </a>
#    (3,892,636 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Idaho.json.gz">
#     metadata
#    </a>
#    (33,214 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Illinois
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Illinois.json.gz">
#     reviews
#    </a>
#    (23,096,838 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Illinois.json.gz">
#     metadata
#    </a>
#    (179,205 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Indiana
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Indiana.json.gz">
#     reviews
#    </a>
#    (12,865,167 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Indiana.json.gz">
#     metadata
#    </a>
#    (100,391 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Iowa
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Iowa.json.gz">
#     reviews
#    </a>
#    (4,838,887 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Iowa.json.gz">
#     metadata
#    </a>
#    (47,794 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Kansas
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Kansas.json.gz">
#     reviews
#    </a>
#    (5,546,880 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Kansas.json.gz">
#     metadata
#    </a>
#    (46,286 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Kentucky
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Kentucky.json.gz">
#     reviews
#    </a>
#    (7,654,993 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Kentucky.json.gz">
#     metadata
#    </a>
#    (63,193 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Louisiana
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Louisiana.json.gz">
#     reviews
#    </a>
#    (7,536,078 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Louisiana.json.gz">
#     metadata
#    </a>
#    (63,315 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Maine
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Maine.json.gz">
#     reviews
#    </a>
#    (2,214,773 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Maine.json.gz">
#     metadata
#    </a>
#    (24,853 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Maryland
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Maryland.json.gz">
#     reviews
#    </a>
#    (10,728,483 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Maryland.json.gz">
#     metadata
#    </a>
#    (78,144 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Massachusetts
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Massachusetts.json.gz">
#     reviews
#    </a>
#    (10,447,007 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-Massachusetts.json.gz">
#     metadata
#    </a>
#    (92,520 businesses)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Michigan
#   </td>
#   <td>
#    <a href="https://d

# %% [markdown]
# ### C. Subset Review Data Table

# %%
display(HTML(subset_data_table.prettify()))
# Out:
# <table class="code-table" style="font-size: 0.7em; width:90%">
#  <tr>
#   <td>
#    Alabama
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Alabama_10.json.gz">
#     10-core
#    </a>
#    (5,146,330 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Alabama.csv.gz">
#     ratings only
#    </a>
#    (8,967,499 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Alaska
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Alaska_10.json.gz">
#     10-core
#    </a>
#    (521,515 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Alaska.csv.gz">
#     ratings only
#    </a>
#    (1,051,246 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Arizona
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Arizona_10.json.gz">
#     10-core
#    </a>
#    (10,764,435 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Arizona.csv.gz">
#     ratings only
#    </a>
#    (18,375,050 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Arkansas
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Arkansas_10.json.gz">
#     10-core
#    </a>
#    (2,855,468 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Arkansas.csv.gz">
#     ratings only
#    </a>
#    (5,106,056 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    California
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-California_10.json.gz">
#     10-core
#    </a>
#    (44,476,890 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-California.csv.gz">
#     ratings only
#    </a>
#    (70,529,977 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Colorado
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Colorado_10.json.gz">
#     10-core
#    </a>
#    (8,738,271 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Colorado.csv.gz">
#     ratings only
#    </a>
#    (15,681,222 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Connecticut
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Connecticut_10.json.gz">
#     10-core
#    </a>
#    (2,680,107 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Connecticut.csv.gz">
#     ratings only
#    </a>
#    (5,181,800 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Delaware
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Delaware_10.json.gz">
#     10-core
#    </a>
#    (905,537 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Delaware.csv.gz">
#     ratings only
#    </a>
#    (1,885,948 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    District of Columbia
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-District_of_Columbia_10.json.gz">
#     10-core
#    </a>
#    (564,783 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-District_of_Columbia.csv.gz">
#     ratings only
#    </a>
#    (1,894,317 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Florida
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Florida_10.json.gz">
#     10-core
#    </a>
#    (35,457,319 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Florida.csv.gz">
#     ratings only
#    </a>
#    (61,803,524 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Georgia
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Georgia_10.json.gz">
#     10-core
#    </a>
#    (13,599,687 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Georgia.csv.gz">
#     ratings only
#    </a>
#    (24,060,125 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Hawaii
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Hawaii_10.json.gz">
#     10-core
#    </a>
#    (1,504,347 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Hawaii.csv.gz">
#     ratings only
#    </a>
#    (3,111,531 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Idaho
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Idaho_10.json.gz">
#     10-core
#    </a>
#    (2,085,487 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Idaho.csv.gz">
#     ratings only
#    </a>
#    (3,892,636 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Illinois
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Illinois_10.json.gz">
#     10-core
#    </a>
#    (13,237,848 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Illinois.csv.gz">
#     ratings only
#    </a>
#    (23,096,838 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Indiana
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Indiana_10.json.gz">
#     10-core
#    </a>
#    (7,638,803 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Indiana.csv.gz">
#     ratings only
#    </a>
#    (12,865,167 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Iowa
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Iowa_10.json.gz">
#     10-core
#    </a>
#    (2,677,684 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Iowa.csv.gz">
#     ratings only
#    </a>
#    (4,838,887 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Kansas
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Kansas_10.json.gz">
#     10-core
#    </a>
#    (3,080,115 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Kansas.csv.gz">
#     ratings only
#    </a>
#    (5,546,880 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Kentucky
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Kentucky_10.json.gz">
#     10-core
#    </a>
#    (4,240,662 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Kentucky.csv.gz">
#     ratings only
#    </a>
#    (7,654,993 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Louisiana
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Louisiana_10.json.gz">
#     10-core
#    </a>
#    (3,985,782 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Louisiana.csv.gz">
#     ratings only
#    </a>
#    (7,536,078 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Maine
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Maine_10.json.gz">
#     10-core
#    </a>
#    (1,123,881 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Maine.csv.gz">
#     ratings only
#    </a>
#    (2,214,773 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Maryland
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Maryland_10.json.gz">
#     10-core
#    </a>
#    (5,590,890 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/rating-Maryland.csv.gz">
#     ratings only
#    </a>
#    (10,728,483 ratings)
#   </td>
#  </tr>
#  <tr>
#   <td>
#    Massachusetts
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Massachusetts_10.json.gz">
#     10-core
#    </a>
#    (5,624,944 reviews)
#   </td>
#   <td>
#    <a href="https://datarepo.eng.ucsd.edu/mcauley_group/gdrive

# %% [markdown]
# ## 4. Extract Download Links<a class="anchor" id="extract"></a>
#
# In this section, we will retrieve the "href" links from the Complete and Subset tables and store them in separate arrays. Specifically, we'll extract the URLs associated with the "href" attribute from anchor tags in both tables and save them in distinct arrays based on their respective tables.

# %% [markdown]
# **Complete Review Data Table:**

# %%
complete_table_rows = complete_data_table.findAll(lambda tag: tag.name=='td')
href_links = [
    row.find('a')['href'] for row in complete_table_rows if row.find('a')
]
complete_review_links = [link for link in href_links if "review" in link]
complete_meta_links = [link for link in href_links if "meta" in link]

# %% [markdown]
# **Subset Review Data Table:**

# %%
subset_table_rows = subset_data_table.findAll(lambda tag: tag.name=='td')
href_links = [
    row.find('a')['href'] for row in subset_table_rows if row.find('a')
]
subset_review_links = [link for link in href_links if "review" in link]
subset_rating_links = [link for link in href_links if "rating" in link]

# %% [markdown]
# **Print sample of download links:**

# %%
complete_review_links
# Out:
# ['https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Alabama.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Alaska.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Arizona.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Arkansas.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-California.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Colorado.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Connecticut.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Delaware.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-District_of_Columbia.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Florida.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Georgia.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Hawaii.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Idaho.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Illinois.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Indiana.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Iowa.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Kansas.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Kentucky.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Louisiana.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Maine.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Maryland.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Massachusetts.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Michigan.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Minnesota.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Mississippi.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Missouri.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Montana.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Nebraska.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Nevada.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-New_Hampshire.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-New_Jersey.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-New_Mexico.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-New_York.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-North_Carolina.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-North_Dakota.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Ohio.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Oklahoma.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Oregon.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Pennsylvania.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Rhode_Island.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-South_Carolina.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-South_Dakota.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Tennessee.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Texas.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Utah.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Vermont.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Virginia.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Washington.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-West_Virginia.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Wisconsin.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-Wyoming.json.gz',
#  'https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-other.json.gz']

# %% [markdown]
# ## 5. Download and Explore Data<a class="anchor" id="download"></a>
#
# In this part, we will download and investigate the initial file from each type of link to identify the necessary data for our project.
#
# **Extract initial URLs:**

# %%
initial_links = [
    complete_review_links[0], 
    complete_meta_links[0], 
    subset_review_links[0], 
    subset_rating_links[0]
]

# %% [markdown]
# **Download the initial files using `download_file` utils function:**

# %%
gzip_folderpath = "../data/gzip"
for url in initial_links:
    download_file(url, gzip_folderpath)
# Out:
# INFO:root:Downloaded and saved to: ../data/gzip/review-Alabama.json.gz
# INFO:root:Downloaded and saved to: ../data/gzip/meta-Alabama.json.gz
# INFO:root:Downloaded and saved to: ../data/gzip/review-Alabama_10.json.gz
# INFO:root:Downloaded and saved to: ../data/gzip/rating-Alabama.csv.gz

# %% [markdown]
# **Read downloaded data into DataFrame:**
#
# `review_dataframe`: First complete review data (Alabama)
# `meta_dataframe`: First complete review metadata (Alabama)
# `subset_review_dataframe`: First subset review data (Alabama)
# `rating_dataframe`: First subset review ratings (Alabama)

# %%
filepaths = [
    os.path.join(gzip_folderpath, link.split("/")[-1]) 
    for link in initial_links
]
review_dataframe, meta_dataframe, subset_review_dataframe, rating_dataframe = [
    parse_into_dataframe(filepath) for filepath in filepaths
]

# %% [markdown]
# **Columns of `review_dataframe`:**
#
# `user_id`: A unique identifier for reviewer.
# `name`: The name of the reviewer.
# `time`: The unix timestamp of when the review was posted.
# `rating`: The rating given by the reviewer for the service or experience.
# `text`: The main content of the review.
# `pics`: A list of dictionaries, where each dictionary contains a URL to an image related to the review.
# `resp`: A dictionary containing the response from the business owner or management. It includes the timestamp of the response and the text of the response.
# `gmap_id`: The Google Maps ID associated with the place or location being reviewed.
#
#
# <div style="background-color: black; color: white; padding: 10px">
#     <p><b>Insight</b>: For our task, the columns of interest are <b>rating</b>, <b>text</b>, <b>resp</b>.</p>
# </div>

# %%
review_dataframe
# Out:
#                        user_id               name           time  rating  \
# 0        103378997989317552200        Hadley Coan  1626307876654     5.0
# 1        112597120686891028387      Macey Johnson  1626309762833     5.0
# 2        100270366925303470748     Kelby Copeland  1626301530535     5.0
# 3        104473837835817861429        Wynn Thomas  1626300613475     5.0
# 4        114435642252064696269          Seth Meek  1624983585963     1.0
# ...                        ...                ...            ...     ...
# 8967494  113553461507404622618  Tahniyath Sultana  1575316959599     5.0
# 8967495  114905707698977221595            Cody Mc  1541393753107     5.0
# 8967496  114609977215690498119          Liam Wood  1499539724361     5.0
# 8967497  105458096176315452031         John Laine  1506555396467     3.0
# 8967498  103340312940951087157   Lorena Ormazabal  1540127172000     1.0
#
#                                                       text  pics  \
# 0        Love this little local shop. I shopped for my ...  None
# 1        The absolute BEST children’s boutique in town!...  None
# 2        The absolute BEST place for children’s clothes...  None
# 3        The best children’s boutique in North Alabama ...  None
# 4        Terrible service. went in to buy 2 bogg bags a...  None
# ...                                                    ...   ...
# 8967494                                               None  None
# 8967495                                               None  None
# 8967496                                               None  None
# 8967497                                               None  None
# 8967498                                               None  None
#
#                                                       resp  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4        {'time': 1624988771302, 'text': 'Hi Seth, my n...
# ...                                                    ...
# 8967494                                               None
# 8967495                                               None
# 8967496                                               None
# 8967497                                               None
# 8967498                                               None
#
#                                        gmap_id
# 0        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 1        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 2        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 3        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 4        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# ...                                        ...
# 8967494  0x888912c75384e095:0x3bf8b383c85ccf97
# 8967495  0x888912c75384e095:0x3bf8b383c85ccf97
# 8967496  0x888912c75384e095:0x3bf8b383c85ccf97
# 8967497  0x888912c75384e095:0x3bf8b383c85ccf97
# 8967498  0x888912c75384e095:0x3bf8b383c85ccf97
#
# [8967499 rows x 8 columns]

# %% [markdown]
# **Columns of `meta_dataframe`:**
#
# `name`: The name of the business.
# `address`: The complete address of the place, including street, city, state, and postal code.
# `gmap_id`: The Google Maps ID associated with the business.
# `description`: The description of the business.
# `latitude`: The latitude coordinate of the business.
# `longitude`: The longitude coordinate of the business.
# `category`: The category of the business.
# `avg_rating`: The average rating of the business.
# `num_of_reviews`: The number of reviews for the business.
# `price`: The price category of the business.
# `hours`: The operating hours of the place, provided as a list of lists, where each inner list contains the day and the corresponding opening and closing time.
# `MISC`: A dictionary containing miscellaneous information about the place, such as service options, health & safety measures, accessibility options, planning details, and accepted payment methods.
# `state`: The current status of the business (e.g., permanently closed)
# `relative_results`: A list of Google Maps IDs related to this place.
# `url` The URL link to the Google Maps page for this place.
#
# <div style="background-color: black; color: white; padding: 10px">
#     <p><b>Insight</b>: The metadata can serve as a good traceback to the main review data which can be matched using <b>gmap_id</b>.</p>
# </div>

# %%
meta_dataframe
# Out:
#                                            name  \
# 0                                 Purple Peanut
# 1                        Posh Mommy & Baby Too!
# 2                    Soccer Shots North Alabama
# 3                            Perdido Pass Jetty
# 4                        Tri-Rx Pharmaceuticals
# ...                                         ...
# 74962                              Aafes Xpress
# 74963                         Redstone Exchange
# 74964               Redstone Arsenal Commissary
# 74965  Renaissance Mobile Riverview Plaza Hotel
# 74966           The Outlet Shops of Grand River
#
#                                                  address  \
# 0      Purple Peanut, 2357 Whitesburg Dr # D, Huntsvi...
# 1      Posh Mommy & Baby Too!, 7755 Hwy 72 W, Madison...
# 2                                                   None
# 3             Perdido Pass Jetty, Orange Beach, AL 36561
# 4      Tri-Rx Pharmaceuticals, 120 Vintage Dr NE, Hun...
# ...                                                  ...
# 74962  Aafes Xpress, 6600 Andrews Ave, Fort Rucker, A...
# 74963            Redstone Exchange, Huntsville, AL 35808
# 74964  Redstone Arsenal Commissary, 3224 Acton Dr, Hu...
# 74965  Renaissance Mobile Riverview Plaza Hotel, 64 S...
# 74966  The Outlet Shops of Grand River, 6200 Grand Ri...
#
#                                      gmap_id  \
# 0      0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 1      0x886268e8fdc4fd2f:0x746533eb9aa4d4df
# 2      0x8862693a967c0ecb:0xb84b19fa307337b0
# 3      0x889a07c7ba3993d5:0xbffff446052a43ed
# 4      0x8862151721b911fd:0xef80131fdd2f539b
# ...                                      ...
# 74962  0x88926454984e0187:0x9ae0a1b39177b83a
# 74963  0x88626c454574ccdf:0xd68e2c9c6da64862
# 74964  0x88626c453e8433e1:0x544837d0ec5f80b9
# 74965  0x889a4fda2fa29c93:0x2a4edb18ef98ea7c
# 74966  0x888912c75384e095:0x3bf8b383c85ccf97
#
#                                              description   latitude  \
# 0                                                   None  34.713163
# 1      Stylish children's shop stocking apparel, mate...  34.753758
# 2                                                   None  34.651859
# 3                                                   None  30.273880
# 4                                                   None  34.791450
# ...                                                  ...        ...
# 74962                                               None  31.323993
# 74963                                               None  34.695399
# 74964                                               None  34.695967
# 74965  Contemporary hotel offering bright rooms, 2 re...  30.690927
# 74966  Modest, contemporary outdoor outlet mall with ...  33.549216
#
#        longitude                                           category  \
# 0     -86.574041                                         [Boutique]
# 1     -86.739241           [Baby store, Children's furniture store]
# 2     -86.765534               [Soccer club, Service establishment]
# 3     -87.559433                                     [Fishing pier]
# 4     -86.532249                                 [Corporate office]
# ...          ...                                                ...
# 74962 -85.723925                                      [Gas station]
# 74963 -86.631584                               [E-commerce service]
# 74964 -86.631386                  [Grocery store, ATM, Supermarket]
# 74965 -88.039327  [Hotel, Indoor lodging, Meeting planning servi...
# 74966 -86.595743                       [Shopping mall, Outlet mall]
#
#        avg_rating  num_of_reviews price  \
# 0             4.6              17  None
# 1             3.9              58  None
# 2             4.7               3  None
# 3             4.7               6  None
# 4             3.7               6  None
# ...           ...             ...   ...
# 74962         4.4              35  None
# 74963         4.4             218  None
# 74964         4.4             618  None
# 74965         4.5            1778  None
# 74966         4.5            4392  None
#
#                                                    hours  \
# 0      [[Thursday, Closed], [Friday, 10AM–5PM], [Satu...
# 1      [[Thursday, 10AM–5:30PM], [Friday, 10AM–5:30PM...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 74962  [[Thursday, 5AM–11PM], [Friday, 5AM–12AM], [Sa...
# 74963  [[Thursday, 10AM–6PM], [Friday, 10AM–6PM], [Sa...
# 74964  [[Thursday, 9AM–7PM], [Friday, 9AM–7PM], [Satu...
# 74965                                               None
# 74966  [[Wednesday, 11AM–7PM], [Thursday, 11AM–7PM], ...
#
#                                                     MISC  \
# 0      {'Service options': ['In-store shopping', 'Del...
# 1      {'Service options': ['In-store shopping', 'Del...
# 2                                                   None
# 3                                                   None
# 4      {'Accessibility': ['Wheelchair accessible entr...
# ...                                                  ...
# 74962  {'Accessibility': ['Wheelchair accessible entr...
# 74963  {'Accessibility': ['Wheelchair accessible entr...
# 74964  {'Service options': ['In-store shopping', 'Del...
# 74965                                               None
# 74966  {'Service options': ['In-store shopping'], 'Ac...
#
#                          state  \
# 0      Closed ⋅ Opens 10AM Fri
# 1         Open ⋅ Closes 5:30PM
# 2                         None
# 3                         None
# 4                         None
# ...                        ...
# 74962                      NaN
# 74963                      NaN
# 74964                      NaN
# 74965                      NaN
# 74966                      NaN
#
#                                         relative_results  \
# 0      [0x886269389730ce8b:0xedffba4037968914, 0x8862...
# 1      [0x88626ca5952a1829:0x263122b2d5a8e211, 0x8862...
# 2      [0x88626ccc2e5fd0d5:0x3c2f2cb8d56688fd, 0x8862...
# 3      [0x889a048d87bce635:0x3241501e0c4524a7, 0x8890...
# 4                                                   None
# ...                                                  ...
# 74962  [0x889264e06b427ea3:0x9e1b581a44d4dc8d, 0x8892...
# 74963  [0x88626c453e8433e1:0x544837d0ec5f80b9, 0x8862...
# 74964  [0x88626c454574ccdf:0xd68e2c9c6da64862, 0x8862...
# 74965                                               None
# 74966  [0x8889177a0699ece7:0x6337ea9fc23726da, 0x8889...
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 74962  https://www.google.com/maps/place//data=!4m2!3...
# 74963  https://www.google.com/maps/place//data=!4m2!3...
# 74964  https://www.google.com/maps/place//data=!4m2!3...
# 74965  https://www.google.com/maps/place//data=!4m2!3...
# 74966  https://www.google.com/maps/place//data=!4m2!3...
#
# [74967 rows x 15 columns]

# %% [markdown]
# **Columns of `subset_review_dataframe`:**
#
# `user_id`: A unique identifier for reviewer.
# `name`: The name of the reviewer.
# `time`: The unix timestamp of when the review was posted.
# `rating`: The rating given by the reviewer for the service or experience.
# `text`: The main content of the review.
# `pics`: A list of dictionaries, where each dictionary contains a URL to an image related to the review.
# `resp`: A dictionary containing the response from the business owner or management. It includes the timestamp of the response and the text of the response.
# `gmap_id`: The Google Maps ID associated with the place or location being reviewed.
#
#
# <div style="background-color: black; color: white; padding: 10px">
#     <p><b>Insight</b>: For our task, the columns of interest are <b>rating</b>, <b>text</b>, <b>resp</b>.</p>
# </div>

# %%
subset_review_dataframe
# Out:
#                        user_id                    name           time  rating  \
# 0        114043824230907811356           Kanisha Mixon  1597168272670       5
# 1        116009008420407071921          Brandie Hodges  1609899039594       5
# 2        106239928178034609776             Sharon King  1547235290843       4
# 3        104970056115801744726         Veronica Pierce  1517709403534       5
# 4        110587471700525107383  Whitney Waldon Collier  1535245718492       5
# ...                        ...                     ...            ...     ...
# 5146325  113553461507404622618       Tahniyath Sultana  1575316959599       5
# 5146326  114905707698977221595                 Cody Mc  1541393753107       5
# 5146327  114609977215690498119               Liam Wood  1499539724361       5
# 5146328  105458096176315452031              John Laine  1506555396467       3
# 5146329  103340312940951087157        Lorena Ormazabal  1540127172000       1
#
#                                                       text  pics  resp  \
# 0        Very Personable staff! Beautiful and clean env...  None  None
# 1                                     Best clothing intown  None  None
# 2                                                     None  None  None
# 3                                                     None  None  None
# 4                                                     None  None  None
# ...                                                    ...   ...   ...
# 5146325                                               None  None  None
# 5146326                                               None  None  None
# 5146327                                               None  None  None
# 5146328                                               None  None  None
# 5146329                                               None  None  None
#
#                                        gmap_id
# 0        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 1        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 2        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 3        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# 4        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf
# ...                                        ...
# 5146325  0x888912c75384e095:0x3bf8b383c85ccf97
# 5146326  0x888912c75384e095:0x3bf8b383c85ccf97
# 5146327  0x888912c75384e095:0x3bf8b383c85ccf97
# 5146328  0x888912c75384e095:0x3bf8b383c85ccf97
# 5146329  0x888912c75384e095:0x3bf8b383c85ccf97
#
# [5146330 rows x 8 columns]

# %% [markdown]
# **Columns of `rating_dataframe`:**
#
# `business`, `user`, `rating`, `timestamp`

# %%
rating_dataframe
# Out:
#                                       business                   user  rating  \
# 0        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf  103378997989317552200       5
# 1        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf  112597120686891028387       5
# 2        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf  100270366925303470748       5
# 3        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf  104473837835817861429       5
# 4        0x8862134e67ff5c87:0x38b5e2ae99cd1fcf  114435642252064696269       1
# ...                                        ...                    ...     ...
# 8902586  0x888912c75384e095:0x3bf8b383c85ccf97  113553461507404622618       5
# 8902587  0x888912c75384e095:0x3bf8b383c85ccf97  114905707698977221595       5
# 8902588  0x888912c75384e095:0x3bf8b383c85ccf97  114609977215690498119       5
# 8902589  0x888912c75384e095:0x3bf8b383c85ccf97  105458096176315452031       3
# 8902590  0x888912c75384e095:0x3bf8b383c85ccf97  103340312940951087157       1
#
#              timestamp
# 0        1626307876654
# 1        1626309762833
# 2        1626301530535
# 3        1626300613475
# 4        1624983585963
# ...                ...
# 8902586  1575316959599
# 8902587  1541393753107
# 8902588  1499539724361
# 8902589  1506555396467
# 8902590  1540127172000
#
# [8902591 rows x 4 columns]

# %% [markdown]
# **Remove initial files from `data/gzip` folder:**

# %%
remove_files_from_folder(gzip_folderpath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 remove_files_from_folder(gzip_folderpath)
#
# NameError: name 'remove_files_from_folder' is not defined

# %% [markdown]
# ## 6. Summary<a class="anchor" id="summary"></a>
#
# This notebook downloads the gzip files and extracts into respective format. After initial exploration, we will proceed to perform a more extensive EDA (Exploratory Data Analysis).
